# %%
import sys
import os
import pandas as pd

# %%
import numpy as np

df = pd.read_csv("../data/processed/train.csv")

actual_log = df["SalePrice"].iloc[0]

actual_price = np.expm1(actual_log)

print("Actual Price:", actual_price)
print("Predicted Price:", 201583)
# Out:
# Actual Price: 208499.99999999983
# Predicted Price: 201583
